# %%
import pandas as pd
import numpy as np

# %%
#Listing.csv

listing_df = pd.read_csv("listings.csv")
listing_df.head(5)
# Out:
#      id                                               name  host_id  \
# 0  2708  Run Runyon, Beaut Furn Mirror Mini-Suit w/ Fir...     3008
# 1  2732                              Zen Life at the Beach     3041
# 2  2864             * Beautiful Master Suite/Jacuzzi Tub/*     3207
# 3  6033                           Poolside Serenity Studio    11619
# 4  6931  RUN Runyon, Beau Furn Rms Terrace Hollyw Hill ...     3008
#
#    host_profile_id     host_name  neighbourhood_group   neighbourhood  \
# 0     1.462506e+18         Chas.  City of Los Angeles       Hollywood
# 1     1.462506e+18  Louise-Diane         Other Cities    Santa Monica
# 2     1.462506e+18     Bernadine         Other Cities      Bellflower
# 3     1.462507e+18         Sarah  City of Los Angeles  Woodland Hills
# 4     1.462506e+18         Chas.  City of Los Angeles       Hollywood
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  34.09625 -118.34605     Private room    NaN              30
# ...

# %%
#Reviews.csv

review_df = pd.read_csv("reviews.csv")
review_df.head()
# Out:
#    listing_id        id        date  reviewer_id     reviewer_name  \
# 0        2708  13994902  2014-06-09     10905424           Kuberan
# 1        2708  14606598  2014-06-23      2247288           Camilla
# 2        2708  39597339  2015-07-25     27974696            Fallon
# 3        2708  61157407  2016-02-01     33226412            Haroon
# 4        2708  66196280  2016-03-20     23408691  Massimo Litterio
#
#                                             comments
# 0  i had a wonderful stay. Everything from start ...
# 1  Charles is just amazing and he made my stay sp...
# 2  Staying with Chas was an absolute pleasure. He...
# 3  Charles is a most wonderful host. I enjoyed my...
# 4  Chas is a really good host. He gives me a lot ...

# %%
#Neighbouthoods.csv

neighbors_df = pd.read_csv("neighbourhoods.csv")
neighbors_df.head()
# Out:
#    neighbourhood_group           neighbourhood
# 0  City of Los Angeles         Adams-Normandie
# 1  City of Los Angeles                  Arleta
# 2  City of Los Angeles       Arlington Heights
# 3  City of Los Angeles         Atwater Village
# 4  City of Los Angeles  Baldwin Hills/Crenshaw

# %%
#Neighbourhood.geojson

import json

with open("neighbourhoods.geojson", "r", encoding="utf-8") as f:
    data = json.load(f)

print(data.keys())          # see structure
print(len(data["features"]))

# First feature
print(data["features"][0])

# First 5 features
print(data["features"][:5])
# Out:
# dict_keys(['type', 'features'])
# 270
# ...
